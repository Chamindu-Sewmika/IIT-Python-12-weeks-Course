# %%
print("My name is Chamindu Wijesinghe")
print ("I am a student at IIT")
print ("I learn python programming")
# Out:
# My name is Chamindu Wijesinghe
# I am a student at IIT
# I learn python programming
