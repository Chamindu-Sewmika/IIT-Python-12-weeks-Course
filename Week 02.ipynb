# %% [markdown]
# ## Variable Decleration & Verification

# %%
x=10
y="Sri Lanka"
z=75.85
print (x)
print (y)
print (z)
# Out:
# 10
# Sri Lanka
# 75.85

# %%
print (type(x))
# Out:
# <class 'int'>

# %%
print (type(y))
# Out:
# <class 'str'>

# %%
print (type(z))
# Out:
# <class 'float'>

# %% [markdown]
# ## Variable Rules

# %%
name="chamindu"
Name="wijesinghe"
print (name+" "+Name)
# Out:
# chamindu wijesinghe

# %%
ABC_=100
print(_aAB_c99_)
# Out:
# 100

# %% [markdown]
# # Arithmatic Operators

# %%
#Addition

# %%
5+2
# Out:
# 7

# %%
#Subtraction

# %%
5-2
# Out:
# 3

# %%
#Multiplication

# %%
5*2
# Out:
# 10

# %%
#Division

# %%
5/2
# Out:
# 2.5

# %%
#Floor Division

# %%
5//2
# Out:
# 2

# %%
#Modulus

# %%
5%2
# Out:
# 1

# %%
#Power

# %%
5**2
# Out:
# 25

# %% [markdown]
# # Assignment Operators

# %%
a=5
b=2
a=b
print(a)
# Out:
# 2

# %%
# B gets the value of A.always,value of the right side assigned to left

# %%
a=5
b=2
a+=b
print(a)
# Out:
# 7

# %%
#Value of A added to B.   a=a+b

# %%
a=5
b=2
a-=b
print(a)
# Out:
# 3

# %%
#Value of B subtracted from A      a=a-b

# %%
a=5
b=2
a*=b
print(a)
# Out:
# 10

# %%
#Value of A multiplied by B             a=a*b

# %%
a=5
b=2
a/=b
print(a)
# Out:
# 2.5

# %%
#Value of A divided by Value of B      a=a/b

# %%
a=5
b=2
a//=b
print(a)
# Out:
# 2

# %%
#a=a//b

# %% [markdown]
# ## Comparison Operators

# %%
a=5
b=3

# %%
#Equal to

# %%
a==b
# Out:
# False

# %%
#Not Equal to

# %%
a!=b
# Out:
# True

# %%
#Greater Than

# %%
a>b
# Out:
# True

# %%
#Less Than

# %%
a<b
# Out:
# False

# %%
#Greater than or Equal

# %%
a>=b
# Out:
# True

# %%
#Less than or Equal

# %%
a<=b
# Out:
# False

# %% [markdown]
# # Logical Operators

# %% [markdown]
# ### NOT

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ### AND

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %% [markdown]
# ### OR

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False
